# %% [markdown]
# 3.  Tasks - To - Do
#
# Please Solve all the Problems as instructed:

# %% [markdown]
# 3.1 Problem - 1
#
# Getting Started with Data Exploration - Some Warm up
#
# Exercises:

# %%
# mounted the drive to link with csv file on colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# 1. Data Exploration and Understanding:
#
#    • Dataset Overview:
#
#        1. Load the dataset and display the first 10 rows.

# %%
# Importing necesseary package
import pandas as pd
# Loading the dataset
dataset_path = '/content/drive/My Drive/Asignment of math/WHR-2024-5CS037.csv'  # using correct file path
df = pd.read_csv(dataset_path)

# Display the first 10 rows
(df.head(10))
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
# 5  Netherlands  7.319               1.901           1.462
# 6       Norway  7.302               1.952           1.517
# 7   Luxembourg  7.122               2.141           1.355
# 8  Switzerland  7.060               1.970           1.425
# 9    Australia  7.057               1.854           1.461
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# ...

# %% [markdown]
# 2.
#
#
#
#  Identify the number of rows and columns in the dataset.

# %%
# getting the number of rows and columns
rows, columns = df.shape

# printing the number of rows and columns from the dataset
print(f"The dataset has {rows} rows and {columns} columns.")
# Out:
# The dataset has 143 rows and 9 columns.

# %% [markdown]
# 3.
#
#
# List all the columns and their data types.

# %%
# Printing the columns with their data types
print("Columns and their data types:")
(df.dtypes)
# Out:
# Columns and their data types:
# Country name                     object
# score                           float64
# Log GDP per capita              float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# Dystopia + residual             float64
# dtype: object

# %% [markdown]
# • Basic Statistics:
#
#    1. Calculate the mean, median, and standard deviation for the Score column.

# %%
df.columns = df.columns.str.strip().str.lower()

column_name = 'score'

if column_name in df.columns:
    mean_score = df[column_name].mean()
    median_score = df[column_name].median()
    std_dev_score = df[column_name].std()

    # Printing the results
    print(f"Mean: {mean_score}")
    print(f"Median: {median_score}")
    print(f"Standard Deviation: {std_dev_score}")
# Out:
# Mean: 5.52758041958042
# Median: 5.785
# Standard Deviation: 1.1707165099442995

# %% [markdown]
# 2. Identify the country with the highest and lowest happiness scores.

# %%
# Loading the dataset with the correct file path
data = pd.read_csv('/content/drive/My Drive/Asignment of math/WHR-2024-5CS037.csv')

country_column = 'Country name'
score_column = 'score'


highest_happiness = data.loc[data[score_column].idxmax()]
lowest_happiness = data.loc[data[score_column].idxmin()]

    # Printing the result of higest happiness score
print("\nCountry with the highest happiness score:")
print(f"{highest_happiness[country_column]} - {highest_happiness[score_column]}")
    # Printing the result of lowest happiness score
print("\nCountry with the lowest happiness score:")
print(f"{lowest_happiness[country_column]} - {lowest_happiness[score_column]}")
# Out:
# Country with the highest happiness score:
# Finland - 7.741
#
# Country with the lowest happiness score:
# Afghanistan - 1.721

# %% [markdown]
# • Missing Values:
#
# 1. Check if there are any missing values in the dataset. If so, display the total count for each column.

# %%
# Load the dataset
file_path = '/content/drive/My Drive/Asignment of math/WHR-2024-5CS037.csv'
data = pd.read_csv(file_path)

missing_values = data.isnull().sum()

print("Missing Values in Each Column:")
print(missing_values)
# printing the missing value from the dataset
missing_columns = missing_values[missing_values > 0]
if not missing_columns.empty:
    print("\nColumns with missing values:")
    print(missing_columns)
# Out:
# Missing Values in Each Column:
# Country name                    0
# score                           0
# Log GDP per capita              3
# Social support                  3
# Healthy life expectancy         3
# Freedom to make life choices    3
# Generosity                      3
# Perceptions of corruption       3
# Dystopia + residual             3
# dtype: int64
#
# Columns with missing values:
# Log GDP per capita              3
# Social support                  3
# Healthy life expectancy         3
# Freedom to make life choices    3
# Generosity                      3
# Perceptions of corruption       3
# Dystopia + residual             3
# dtype: int64

# %% [markdown]
# • Filtering and Sorting:
#
# 1. Filter the dataset to show only the countries with a Score greater than 7.5.

# %%
# Load the dataset with the correct file path rom drive
file_path = '/content/drive/My Drive/Asignment of math/WHR-2024-5CS037.csv'
data = pd.read_csv(file_path)


country_column = 'Country name'
score_column = 'score'

# Filter the dataset
filtered_data = data[data[score_column] > 7.5]

# prnting  the filtered data of happiness score
print("Countries with a Happiness Score greater than 7.5:")
print(filtered_data[[country_column, score_column]])
# Out:
# Countries with a Happiness Score greater than 7.5:
#   Country name  score
# 0      Finland  7.741
# 1      Denmark  7.583
# 2      Iceland  7.525

# %% [markdown]
# 2. For the filtered dataset - Sort the dataset by GDP per Capita in descending order and display the
# top 10 rows.

# %%
# Load the dataset
file_path = '/content/drive/My Drive/Asignment of math/WHR-2024-5CS037.csv'
data = pd.read_csv(file_path)

sort = data.sort_values(by='Log GDP per capita', ascending=False)
print(sort[['Country name', 'Log GDP per capita']].head(10))
# Out:
#                  Country name  Log GDP per capita
# 7                  Luxembourg               2.141
# 16                    Ireland               2.129
# 29                  Singapore               2.118
# 21       United Arab Emirates               1.983
# 8                 Switzerland               1.970
# 6                      Norway               1.952
# 22              United States               1.939
# 85  Hong Kong S.A.R. of China               1.909
# 1                     Denmark               1.908
# 5                 Netherlands               1.901

# %% [markdown]
# Adding New Columns:
#
#
# 1. Create a new column called Happiness Category that categorizes countries into three categories
# based on their Score:
# Low− (Score < 4)
#
# Medium− (4 ≤ Score ≤ 6)
#
# High− (Score > 6)

# %%
# Load the dataset with correct file path
file_path = '/content/drive/My Drive/Asignment of math/WHR-2024-5CS037.csv'
data = pd.read_csv(file_path)

print("Columns in the dataset:", data.columns)

# checking the happiness score column exist
score_column = 'score'

def categorize_happiness(score):
    if score < 4:
        return 'Low'
    elif 4 <= score <= 6:
        return 'Medium'
    else:
        return 'High'

if score_column in data.columns:
    data['Happiness Category'] = data[score_column].apply(categorize_happiness)
# printing the updated dataset of the happiness category
print("\nUpdated dataset with 'Happiness Category':")
print(data[['Country name', score_column, 'Happiness Category']].head(130))
# Out:
# Columns in the dataset: Index(['Country name', 'score', 'Log GDP per capita', 'Social support',
#        'Healthy life expectancy', 'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Dystopia + residual'],
#       dtype='object')
#
# Updated dataset with 'Happiness Category':
#     Country name  score Happiness Category
# 0        Finland  7.741               High
# 1        Denmark  7.583               High
# 2        Iceland  7.525               High
# 3         Sweden  7.344               High
# 4         Israel  7.341               High
# ..           ...    ...                ...
# 125        India  4.054             Medium
# 126        Egypt  3.977                Low
# 127    Sri Lanka  3.898                Low
# 128   Bangladesh  3.886                Low
# 129     Ethiopia  3.861                Low
#
# [130 rows x 3 columns]

# %% [markdown]
# 2. Data Visualizations:

# %% [markdown]
# • Bar Plot: Plot the top 10 happiest countries by Score using a bar chart.

# %%
import matplotlib.pyplot as plt

data = pd.read_csv('/content/drive/My Drive/Asignment of math/WHR-2024-5CS037.csv')

data.columns = data.columns.str.strip().str.lower()

score_column = 'score'
country_column = 'country name'

top_10_countries = data.nlargest(10, score_column)

# Extract country names and scores
countries = top_10_countries[country_column]
scores = top_10_countries[score_column]

# Creates the bar plot of top 10 happiest country
plt.figure(figsize=(10, 6))
plt.bar(countries, scores, color='green',label=score_column)  #syntax for bar plot
plt.xlabel('Country Name', fontsize=12)
plt.legend()
plt.ylabel('Score', fontsize=12)
plt.title('Top 10 Happiest Countries by Score', fontsize=16)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()  # checking layout is fitting well or not

# Show the plot
plt.show()

# %% [markdown]
# • Line Plot: Plot the top 10 unhappiest countries by Score using a Line chart.

# %%
# loading the dataset with correct file path from the drive
file_path = '/content/drive/My Drive/Asignment of math/WHR-2024-5CS037.csv'
data = pd.read_csv(file_path)

required_columns = ['Country name', 'score']
if all(column in data.columns for column in required_columns):
    bottom_10_countries = data.nsmallest(10, 'score')

    countries = bottom_10_countries['Country name']
    scores = bottom_10_countries['score']

    # Create the line plot for to 10 unhappiest countries by score
    plt.figure(figsize=(10, 6))
    plt.plot(countries, scores, marker='o', color='red',label=score_column ,linestyle='-')
    plt.xlabel('Countries', fontsize=12)
    plt.legend()
    plt.ylabel('Happiness Score', fontsize=12)
    plt.title('Top 10 Unhappiest Countries by Score', fontsize=16)
    plt.xticks(rotation=45, ha='right', fontsize=10)
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.tight_layout()

    # Show the plot
    plt.show()

# %% [markdown]
# • Plot a histogram for the Score column to show its distribution and also interpret.

# %%
# Load the dataset form the drive using actual path
file_path = '/content/drive/My Drive/Asignment of math/WHR-2024-5CS037.csv'
data = pd.read_csv(file_path)

# Making sure that score column is avilable or not in dataset
if 'score' in data.columns:
    # Ploting the histogram
    plt.figure(figsize=(10, 6))
    plt.hist(data['score'], bins=15, color='orange', edgecolor='black',label=score_column, alpha=0.7)
    plt.xlabel('Happiness Score', fontsize=12)
    plt.legend()
    plt.ylabel('Frequency', fontsize=12)
    plt.title('Distribution of Happiness Scores', fontsize=16)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()

    # Show the plot
    plt.show()

# %% [markdown]
# • Scatter Plot: Plot a scatter plot between GDP per Capita and Score to visualize their relationship.

# %%
# Load the dataset
file_path = '/content/drive/My Drive/Asignment of math/WHR-2024-5CS037.csv'
data = pd.read_csv(file_path)

if 'Log GDP per capita' in data.columns and 'score' in data.columns:
    # Ploting the scatter plot
    plt.figure(figsize=(10, 6))
    plt.scatter(data['Log GDP per capita'], data['score'], color='blue', alpha=0.7, edgecolor='k', label='Countries')  # Adding legend label here
    plt.xlabel('GDP per Capita', fontsize=12)
    plt.ylabel('Happiness Score', fontsize=12)
    plt.title('Scatter Plot of GDP per Capita vs Happiness Score', fontsize=16)
    plt.legend()  # Adding the legend here
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()

    # Show the plot
    plt.show()

# %% [markdown]
# 3.2 Problem - 2 - Some Advance Data Exploration Task:

# %% [markdown]
# Task - 1 - Setup Task - Preparing the South-Asia Dataset:

# %% [markdown]
# Steps:
# 1. Define the countries in South Asia with a list for example:
# south asian countries = ["Afghanistan", "Bangladesh", "Bhutan", "India",
# "Maldives", "Nepal", "Pakistan", "Srilanka"]

# %%
# Defining the South Asian countries
south_asian_countries = ["Afghanistan", "Bangladesh", "Bhutan", "India",
                         "Maldives", "Nepal", "Pakistan", "Sri Lanka"]
print(f"south asian countries are {list [south_asian_countries]}")
# Out:
# south asian countries are list[['Afghanistan', 'Bangladesh', 'Bhutan', 'India', 'Maldives', 'Nepal', 'Pakistan', 'Sri Lanka']]

# %% [markdown]
# 2. Use the list from step - 1 to filtered the dataset {i.e. filtered out matching dataset from list.}

# %%
import pandas as pd

#  Definthe South Asian countries
south_asian_countries = ["Afghanistan", "Bangladesh", "Bhutan", "India",
                         "Maldives", "Nepal", "Pakistan", "Sri Lanka"]

#  Load the dataset with proper file path from drive
file_path = '/content/drive/My Drive/Asignment of math/WHR-2024-5CS037.csv'
data = pd.read_csv(file_path)

south_asia_data = data[data['Country name'].isin(south_asian_countries)]

print("Filtered South Asia Dataset:")
print(south_asia_data)

# save the filtered dataset
south_asia_data.to_csv('/content/South_Asia_Dataset.csv', index=False)
# Out:
# Filtered South Asia Dataset:
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 127    Sri Lanka  3.898               1.361           1.179
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
# 127                    0.586                         0.583       0.144
# 128                    0.513                         0.775       0.140
# 142                    0.242                         0.000       0.091
#
# ...

# %% [markdown]
# 3. Save the filtered dataframe as separate CSV files for future use.

# %%
#  Defining the South Asian countries
south_asian_countries = ["Afghanistan", "Bangladesh", "Bhutan", "India",
                         "Maldives", "Nepal", "Pakistan", "Sri Lanka"]

# Loaded the dataset
file_path = '/content/drive/My Drive/Asignment of math/WHR-2024-5CS037.csv'
data = pd.read_csv(file_path)

south_asia_data = data[data['Country name'].isin(south_asian_countries)]

output_path = '/content/drive/My Drive/Asignment of math/South_Asia_Dataset.csv'
south_asia_data.to_csv(output_path, index=False)

print(f"Filtered South Asia dataset saved to: {output_path}")
# Out:
# Filtered South Asia dataset saved to: /content/drive/My Drive/Asignment of math/South_Asia_Dataset.csv

# %% [markdown]
# ![Screenshot 2024-12-18 at 12.07.28 am.png](data:image/png;base64,...)

# %% [markdown]
# Task - 2 - Composite Score Ranking:

# %% [markdown]
# Tasks:
#
# 1. Using the SouthAsia DataFrame, create a new column called Composite Score that combines the
# following metrics:
#
# Composite Score = 0.40 × GDP per Capita + 0.30 × Social Support
# + 0.30 × Healthy Life Expectancy

# %%
# Load the dataset
file_path = '/content/drive/My Drive/Asignment of math/WHR-2024-5CS037.csv' # using the right path of file from drive
south_asia_data = pd.read_csv(file_path)

# List of South Asian countries
south_asian_countries = [
    "Afghanistan", "Bangladesh", "Bhutan", "India", "Maldives", "Nepal", "Pakistan", "Sri Lanka"
]

south_asia_data_filtered = south_asia_data[south_asia_data['Country name'].isin(south_asian_countries)].copy()

required_columns = ['Log GDP per capita', 'Social support', 'Healthy life expectancy']
if all(column in south_asia_data_filtered.columns for column in required_columns):
    # Calculate the Composite Score
    south_asia_data_filtered['Composite Score'] = (
        0.40 * south_asia_data_filtered['Log GDP per capita'] +
        0.30 * south_asia_data_filtered['Social support'] +
        0.30 * south_asia_data_filtered['Healthy life expectancy']
    )

    print(south_asia_data_filtered[['Country name', 'Composite Score']])
# Out:
#     Country name  Composite Score
# 92         Nepal           0.8159
# 107     Pakistan           0.7039
# 125        India           0.7874
# 127    Sri Lanka           1.0739
# 128   Bangladesh           0.6774
# 142  Afghanistan           0.3238

# %% [markdown]
# 2. Rank the South Asian countries based on the Composite Score in descending order.

# %%
import pandas as pd

# Load the dataset
file_path = '/content/drive/My Drive/Asignment of math/WHR-2024-5CS037.csv'
south_asia_data = pd.read_csv(file_path)

# List of South Asian countries
south_asian_countries = [
    "Afghanistan", "Bangladesh", "Bhutan", "India", "Maldives", "Nepal", "Pakistan", "Sri Lanka"
]

south_asia_data_filtered = south_asia_data[south_asia_data['Country name'].isin(south_asian_countries)].copy()

required_columns = ['Log GDP per capita', 'Social support', 'Healthy life expectancy']
if all(column in south_asia_data_filtered.columns for column in required_columns):
    # Calculate the Composite Score
    south_asia_data_filtered['Composite Score'] = (
        0.40 * south_asia_data_filtered['Log GDP per capita'] +
        0.30 * south_asia_data_filtered['Social support'] +
        0.30 * south_asia_data_filtered['Healthy life expectancy']
    )

    ranked_south_asia_data = south_asia_data_filtered.sort_values(by='Composite Score', ascending=False)

    print(ranked_south_asia_data[['Country name', 'Composite Score']])
# Out:
#     Country name  Composite Score
# 127    Sri Lanka           1.0739
# 92         Nepal           0.8159
# 125        India           0.7874
# 107     Pakistan           0.7039
# 128   Bangladesh           0.6774
# 142  Afghanistan           0.3238

# %% [markdown]
# 3. Visualize the top 5 countries using a horizontal bar chart showing the Composite Score.

# %%
# Load the dataset
file_path = '/content/drive/My Drive/Asignment of math/WHR-2024-5CS037.csv'
south_asia_data = pd.read_csv(file_path)

# List of South Asian countries
south_asian_countries = [
    "Afghanistan", "Bangladesh", "Bhutan", "India", "Maldives", "Nepal", "Pakistan", "Sri Lanka"
]

south_asia_data_filtered = south_asia_data[south_asia_data['Country name'].isin(south_asian_countries)].copy()

required_columns = ['Log GDP per capita', 'Social support', 'Healthy life expectancy']
if all(column in south_asia_data_filtered.columns for column in required_columns):
    south_asia_data_filtered['Composite Score'] = (
        0.40 * south_asia_data_filtered['Log GDP per capita'] +
        0.30 * south_asia_data_filtered['Social support'] +
        0.30 * south_asia_data_filtered['Healthy life expectancy']
    )

    countries_to_visualize = ['India', 'Nepal', 'Pakistan', 'Sri Lanka', 'Bangladesh']

    countries_data = south_asia_data_filtered[south_asia_data_filtered['Country name'].isin(countries_to_visualize)]

    # Create a horizontal bar chart
    plt.figure(figsize=(10, 6))
    plt.barh(countries_data['Country name'], countries_data['Composite Score'], color='lightgreen',label=score_column)
    plt.xlabel('Composite Score')
    plt.legend()
    plt.grid(axis='x')
    plt.title('South Asian Countries by Composite Score')

    # Show the plot
    plt.show()

# %% [markdown]
# 4. Discuss whether the rankings based on the Composite Score align with the original Score -
#
#
# support your
# discussion with some visualization plot.

# %% [markdown]
# => The Observing and Visualization:
#
# Here is the comparision of the composite and happiness score that
# offers insight into the relationship between the two metrics. For a strong correlation a linear trend can indicate alignment between two score.

# %%
file_path = '/content/drive/My Drive/Asignment of math/WHR-2024-5CS037.csv'
south_asia_data = pd.read_csv(file_path)

# Ensure column names match the dataset
if 'Composite Score' in south_asia_data_filtered.columns and 'score' in south_asia_data_filtered.columns:
    plt.figure(figsize=(10, 6))
    plt.scatter(
        south_asia_data_filtered['Composite Score'],
        south_asia_data_filtered['score'],
        color='blue',
        label='Countries'
    )

    plt.xlabel('Composite Score', fontsize=12)
    plt.ylabel('Happiness Score', fontsize=12)
    plt.title('Comparison of Composite Score vs Original Happiness Score', fontsize=14)
    plt.grid(True)
    plt.legend()
    plt.show()

    ranked_composite = south_asia_data_filtered.sort_values(by='Composite Score', ascending=False)
    ranked_original = south_asia_data_filtered.sort_values(by='score', ascending=False)

    # Display rankings
    print("\nRanked South Asian Countries by Composite Score:")
    print(ranked_composite[['Country name', 'Composite Score']])

    print("\nRanked South Asian Countries by Original Score:")
    print(ranked_original[['Country name', 'score']])
else:
    print("Error: Required columns ('Composite Score' and/or 'score') not found in the dataset.")
# Out:
# Ranked South Asian Countries by Composite Score:
#     Country name  Composite Score
# 127    Sri Lanka           1.0739
# 92         Nepal           0.8159
# 125        India           0.7874
# 107     Pakistan           0.7039
# 128   Bangladesh           0.6774
# 142  Afghanistan           0.3238
#
# Ranked South Asian Countries by Original Score:
#     Country name  score
# 92         Nepal  5.158
# 107     Pakistan  4.657
# 125        India  4.054
# 127    Sri Lanka  3.898
# 128   Bangladesh  3.886
# 142  Afghanistan  1.721

# %% [markdown]
# Task - 3 - Outlier Detection:

# %% [markdown]
# Tasks:
# 1. Identify outlier countries in South Asia based on their Score and GDP per Capita.

# %%
# Load the dataset
file_path = '/content/drive/My Drive/Asignment of math/WHR-2024-5CS037.csv'
south_asia_data = pd.read_csv(file_path)


q1_score = south_asia_data_filtered['score'].quantile(0.25)
q3_score = south_asia_data_filtered['score'].quantile(0.75)
iqr_score = q3_score - q1_score

q1_gdp = south_asia_data_filtered['Log GDP per capita'].quantile(0.25)
q3_gdp = south_asia_data_filtered['Log GDP per capita'].quantile(0.75)
iqr_gdp = q3_gdp - q1_gdp

lower_bound_score = q1_score - 1.5 * iqr_score
upper_bound_score = q3_score + 1.5 * iqr_score

lower_bound_gdp = q1_gdp - 1.5 * iqr_gdp
upper_bound_gdp = q3_gdp + 1.5 * iqr_gdp

outliers = south_asia_data_filtered[
    (south_asia_data_filtered['score'] < lower_bound_score) |
    (south_asia_data_filtered['score'] > upper_bound_score) |
    (south_asia_data_filtered['Log GDP per capita'] < lower_bound_gdp) |
    (south_asia_data_filtered['Log GDP per capita'] > upper_bound_gdp)
]

# Display outliers
print("Outlier Countries in South Asia based on Score and GDP per Capita:")
print(outliers[['Country name', 'score', 'Log GDP per capita']])
# Out:
# Outlier Countries in South Asia based on Score and GDP per Capita:
#     Country name  score  Log GDP per capita
# 142  Afghanistan  1.721               0.628

# %% [markdown]
# 2. Define outliers using the 1.5 × IQR rule.

# %% [markdown]
#  => According to 1.5*IQR rule we can say that outliers are data points that are different from the rest of the dataset. 1.5*IQR rule is commont method that is used to detect the ouliers which is based on IQR. The difference between q3 and q1 (IQR=q3-q1)is  determined by lower and upper Bounds.
#
#  We calculate lower and upper bounds:
#
#  i>lower bounds=q1-1.5*IQR
#
#  ii>upper bounds=q3+1.5*IQR
#
# After all we can say that any of the data points which is above the upper bonds or below the lower bonds are called outlier.To identify the value which are far from the majority of data will helps to find from this method.

# %% [markdown]
#  3. Create a scatter plot with GDP per Capita on the x-axis and Score on the y-axis, highlighting outliers
# in a different color.

# %%
# Load the dataset
file_path = '/content/drive/My Drive/Asignment of math/WHR-2024-5CS037.csv'
south_asia_data = pd.read_csv(file_path)
print(south_asia_data.head(10))

q1_score = south_asia_data_filtered['score'].quantile(0.25)
q3_score = south_asia_data_filtered['score'].quantile(0.75)
iqr_score = q3_score - q1_score

q1_gdp = south_asia_data_filtered['Log GDP per capita'].quantile(0.25)
q3_gdp = south_asia_data_filtered['Log GDP per capita'].quantile(0.75)
iqr_gdp = q3_gdp - q1_gdp

lower_bound_score = q1_score - 1.5 * iqr_score
upper_bound_score = q3_score + 1.5 * iqr_score

lower_bound_gdp = q1_gdp - 1.5 * iqr_gdp
upper_bound_gdp = q3_gdp + 1.5 * iqr_gdp

outliers = south_asia_data_filtered[
    (south_asia_data_filtered['score'] < lower_bound_score) |
    (south_asia_data_filtered['score'] > upper_bound_score) |
    (south_asia_data_filtered['Log GDP per capita'] < lower_bound_gdp) |
    (south_asia_data_filtered['Log GDP per capita'] > upper_bound_gdp)
]

non_outliers = south_asia_data_filtered[~south_asia_data_filtered.index.isin(outliers.index)]

# Creating scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(
    non_outliers['Log GDP per capita'],
    non_outliers['score'],
    color='blue',
    label='Non-Outliers'
)
plt.scatter(
    outliers['Log GDP per capita'],
    outliers['score'],
    color='red',
    label='Outliers'
)

# Adding labels and title
plt.xlabel('Log GDP per Capita', fontsize=12)
plt.ylabel('Happiness Score', fontsize=12)
plt.title('GDP per Capita vs Happiness Score with Outliers Highlighted', fontsize=14)
plt.legend()
plt.grid(True)
plt.show()
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
# 5  Netherlands  7.319               1.901           1.462
# 6       Norway  7.302               1.952           1.517
# 7   Luxembourg  7.122               2.141           1.355
# 8  Switzerland  7.060               1.970           1.425
# 9    Australia  7.057               1.854           1.461
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# ...

# %% [markdown]
# 4. Discuss the characteristics of these outliers and their potential impact on regional averages.

# %% [markdown]
#    => Here is the disscusion characteristics of these outliers and their potential impact on regional averages.
#
#
# Outliers, whether they are based on GDP per capita or Happiness Score, provide important insights into the diversity of South Asian countries. They highlight the regions of high achievement and areas of struggle, influencing both the average values and the interpretation of regional data. Identifying and understanding outliers is essential for accurately assessing the overall well-being of the region and for implementing more targeted and effective policy measures.

# %% [markdown]
# Task - 4 - Exploring Trends Across Metrics:

# %% [markdown]
# Tasks:
#
# 1. Choose two metrics (e.g., Freedom to Make Life Choices and Generosity) and calculate their correlation
# {pearson correlation} with the Score for South Asian countries.

# %%
# Load the dataset
file_path = '/content/drive/My Drive/Asignment of math/WHR-2024-5CS037.csv'
south_asia_data = pd.read_csv(file_path)

# List of South Asian countries
south_asian_countries = [
    "Afghanistan", "Bangladesh", "Bhutan", "India", "Maldives", "Nepal", "Pakistan", "Sri Lanka"
]

south_asia_data_filtered = south_asia_data[south_asia_data['Country name'].isin(south_asian_countries)].copy()

required_columns = ['Freedom to make life choices', 'Generosity', 'score']
if all(column in south_asia_data_filtered.columns for column in required_columns):
    correlation_freedom_score = south_asia_data_filtered['Freedom to make life choices'].corr(south_asia_data_filtered['score'])

    correlation_generosity_score = south_asia_data_filtered['Generosity'].corr(south_asia_data_filtered['score'])

    # Display the results
    print(f"Pearson correlation between 'Freedom to Make Life Choices' and 'Score': {correlation_freedom_score:.2f}")
    print(f"Pearson correlation between 'Generosity' and 'Score': {correlation_generosity_score:.2f}")

else:
    print("The dataset is missing one or more required columns:", required_columns)
# Out:
# Pearson correlation between 'Freedom to Make Life Choices' and 'Score': 0.80
# Pearson correlation between 'Generosity' and 'Score': 0.87

# %% [markdown]
# 2. Create scatter plots with trendlines for these metrics against the Score.

# %%
import seaborn as sns

# Load the dataset
file_path = '/content/drive/My Drive/Asignment of math/WHR-2024-5CS037.csv'
south_asia_data = pd.read_csv(file_path)

# List of South Asian countries
south_asian_countries = [
    "Afghanistan", "Bangladesh", "Bhutan", "India", "Maldives", "Nepal", "Pakistan", "Sri Lanka"
]

south_asia_data_filtered = south_asia_data[south_asia_data['Country name'].isin(south_asian_countries)].copy()

# Ensure the required columns exist
required_columns = ['Freedom to make life choices', 'Generosity', 'score']
if all(column in south_asia_data_filtered.columns for column in required_columns):
    plt.figure(figsize=(10, 6))
    sns.regplot(x='Freedom to make life choices', y='score', data=south_asia_data_filtered, scatter_kws={'color': 'blue'}, line_kws={'color': 'red'})
    plt.title('Scatter Plot with Trendline: Freedom to Make Life Choices vs Score')
    plt.xlabel('Freedom to Make Life Choices')
    plt.ylabel('Happiness Score')
    plt.grid(True)
    plt.legend(['Trendline', 'Data points'], loc='best')  # Adding legend
    plt.show()

    plt.figure(figsize=(10, 6))
    sns.regplot(x='Generosity', y='score', data=south_asia_data_filtered, scatter_kws={'color': 'green'}, line_kws={'color': 'orange'})
    plt.title('Scatter Plot with Trendline: Generosity vs Score')
    plt.xlabel('Generosity')
    plt.ylabel('Happiness Score')
    plt.grid(True)
    plt.legend(['Trendline', 'Data points'], loc='best')  # Adding legend
    plt.show()

else:
    print("The dataset is missing one or more required columns:", required_columns)

# %% [markdown]
# 3. Identify and discuss the strongest and weakest relationships between these metrics and the Score for
# South Asian countries.

# %% [markdown]
# =>.  First we  make the steps :
#
# i>analyze the pearson correlation coefficient
#
# ii>interpreting the scatter plots and trend lines
#
# iii> identifying the strongest and weakest relationship
#
# According to these steps we implement the score for south asian countries.
#
# a>Generosity: The pearson  correlation  with happiness score is near 0 or weak  that means generosity doesn't i pact on happiness score of south asian countries. The relationship may be very weak because the scatter plot may not show clear.
#
# b>Freedom to make a choice :  When the person's correlation is strong  and positive with their happiness score, we can say that they have greater freedom to make life choices which are associated with higher happiness scores.

# %% [markdown]
# Task - 5 - Gap Analysis:

# %% [markdown]
# Tasks:
# 1. Add a new column, GDP-Score Gap, which is the difference between GDP per Capita and the Score
# for each South Asian country.

# %%
# Load the dataset
file_path = '/content/drive/My Drive/Asignment of math/WHR-2024-5CS037.csv'
south_asia_data = pd.read_csv(file_path)

# List of South Asian countries
south_asian_countries = [
    "Afghanistan", "Bangladesh", "Bhutan", "India", "Maldives", "Nepal", "Pakistan", "Sri Lanka"
]

south_asia_data_filtered = south_asia_data[south_asia_data['Country name'].isin(south_asian_countries)].copy()

required_columns = ['Log GDP per capita', 'score']
if all(column in south_asia_data_filtered.columns for column in required_columns):
    south_asia_data_filtered['GDP-Score Gap'] = south_asia_data_filtered['Log GDP per capita'] - south_asia_data_filtered['score']

    # Display the updated DataFrame
    print(south_asia_data_filtered[['Country name', 'Log GDP per capita', 'score', 'GDP-Score Gap']])

else:
    print("The dataset is missing one or more required columns:", required_columns)
# Out:
#     Country name  Log GDP per capita  score  GDP-Score Gap
# 92         Nepal               0.965  5.158         -4.193
# 107     Pakistan               1.069  4.657         -3.588
# 125        India               1.166  4.054         -2.888
# 127    Sri Lanka               1.361  3.898         -2.537
# 128   Bangladesh               1.122  3.886         -2.764
# 142  Afghanistan               0.628  1.721         -1.093

# %% [markdown]
# 2. Rank the South Asian countries by this gap in both ascending and descending order.

# %%
# Load the dataset
file_path = '/content/drive/My Drive/Asignment of math/WHR-2024-5CS037.csv'
south_asia_data = pd.read_csv(file_path)

# List of South Asian countries
south_asian_countries = [
    "Afghanistan", "Bangladesh", "Bhutan", "India", "Maldives", "Nepal", "Pakistan", "Sri Lanka"
]

south_asia_data_filtered = south_asia_data[south_asia_data['Country name'].isin(south_asian_countries)].copy()

south_asia_data_filtered['GDP-Score Gap'] = south_asia_data_filtered['Log GDP per capita'] - south_asia_data_filtered['score']

# Rank countries by GDP-Score Gap in ascending order
ranked_ascending = south_asia_data_filtered.sort_values(by='GDP-Score Gap', ascending=True)

# Rank countries by GDP-Score Gap in descending order
ranked_descending = south_asia_data_filtered.sort_values(by='GDP-Score Gap', ascending=False)

# Display rankings
print("South Asian Countries Ranked by GDP-Score Gap (Ascending):")
print(ranked_ascending[['Country name', 'GDP-Score Gap']])

print("\nSouth Asian Countries Ranked by GDP-Score Gap (Descending):")
print(ranked_descending[['Country name', 'GDP-Score Gap']])
# Out:
# South Asian Countries Ranked by GDP-Score Gap (Ascending):
#     Country name  GDP-Score Gap
# 92         Nepal         -4.193
# 107     Pakistan         -3.588
# 125        India         -2.888
# 128   Bangladesh         -2.764
# 127    Sri Lanka         -2.537
# 142  Afghanistan         -1.093
#
# South Asian Countries Ranked by GDP-Score Gap (Descending):
#     Country name  GDP-Score Gap
# 142  Afghanistan         -1.093
# 127    Sri Lanka         -2.537
# 128   Bangladesh         -2.764
# 125        India         -2.888
# 107     Pakistan         -3.588
# 92         Nepal         -4.193

# %% [markdown]
# 3. Highlight the top 3 countries with the largest positive and negative gaps
# using a bar chart.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
file_path = '/content/drive/My Drive/Asignment of math/WHR-2024-5CS037.csv'
south_asia_data = pd.read_csv(file_path)

# List of South Asian countries
south_asian_countries = [
    "Afghanistan", "Bangladesh", "Bhutan", "India", "Maldives", "Nepal", "Pakistan", "Sri Lanka"
]

south_asia_data_filtered = south_asia_data[south_asia_data['Country name'].isin(south_asian_countries)].copy()

# Calculate the GDP-Score Gap
south_asia_data_filtered['GDP-Score Gap'] = south_asia_data_filtered['Log GDP per capita'] - south_asia_data_filtered['score']

# Rank countries by GDP-Score Gap in ascending order
ranked_ascending = south_asia_data_filtered.sort_values(by='GDP-Score Gap', ascending=True)

# Rank countries by GDP-Score Gap in descending order
ranked_descending = south_asia_data_filtered.sort_values(by='GDP-Score Gap', ascending=False)

# Get the top 3 positive and negative gaps
top_positive_gap = ranked_descending.head(3)  # Top 3 positive GDP-Score gaps
top_negative_gap = ranked_ascending.head(3)   # Top 3 negative GDP-Score gaps

# Plotting the bar chart
plt.figure(figsize=(10, 6))

# Positive gaps in green and negative gaps in red
plt.barh(top_positive_gap['Country name'], top_positive_gap['GDP-Score Gap'], color='green', label='Positive Gap')
plt.barh(top_negative_gap['Country name'], top_negative_gap['GDP-Score Gap'], color='red', label='Negative Gap')

# Adding title and labels
plt.title('Top 3 Countries with Largest Positive and Negative GDP-Score Gaps', fontsize=14)
plt.xlabel('GDP-Score Gap', fontsize=12)
plt.ylabel('Country', fontsize=12)

# Adding grid and legend
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(fontsize=10)

# Adjusting layout and displaying the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# 4. Analyze the reasons behind these gaps and their implications for South Asian countries.

# %% [markdown]
# =>The reason behind these gaps are economic growth vs well being of top countries with positive  gaps (high gdp score , low happiness score). And those countries with negative gaps(low GDP, high happiness score).
# Implication for south asian countries are listed below:
#
# 1> Policy Adjustment :Policymaker not only focus on economics but also  impact the well being .
#
# 2> well-being : Those countries which have large negative gaps have the opportunity to focus on strengthening mental health.
#
# 3>Holistic development: Reducing corruption and improving governance.

# %% [markdown]
# 3.3  Problem - 3 - Comparative Analysis:

# %% [markdown]
# Task - 1 - Setup Task - Preparing the Middle Eastern Dataset:

# %% [markdown]
# Tasks:
#
# 1. Similar in Task - 1 of Problem 2 create a dataframe from middle eastern countries. For hint use the
# following list:
#
# middle east countries = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan",
# "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria",
# "United Arab Emirates", "Yemen"]

# %% [markdown]
# Complete the following task:

# %% [markdown]
# 1. Descriptive Statistics:
#
# • Calculate the mean, Standard deviation of the score for both South Asia and Middle East.

# %%
# Load the dataset
file_path = '/content/drive/My Drive/Asignment of math/WHR-2024-5CS037.csv'
data = pd.read_csv(file_path)

# List of Middle Eastern countries
middle_east_countries = [
    "Bahrain", "Iran", "Iraq", "Israel", "Jordan", "Kuwait", "Lebanon", "Oman",
    "Palestine", "Qatar", "Saudi Arabia", "Syria", "United Arab Emirates", "Yemen"
]

# List of South Asian countries
south_asian_countries = [
    "Afghanistan", "Bangladesh", "Bhutan", "India", "Maldives", "Nepal", "Pakistan", "Sri Lanka"
]

south_asia_data = data[data['Country name'].isin(south_asian_countries)]

middle_east_data = data[data['Country name'].isin(middle_east_countries)]

if 'score' in data.columns:
    # Calculate mean and standard deviation for South Asia
    south_asia_mean_score = south_asia_data['score'].mean()
    south_asia_std_score = south_asia_data['score'].std()

    # Calculate mean and standard deviation for Middle East
    middle_east_mean_score = middle_east_data['score'].mean()
    middle_east_std_score = middle_east_data['score'].std()

    # Display the results
    print("Analysis of Happiness Scores:")
    print("===================================")
    print("South Asia:")
    print(f"  Mean Score: {south_asia_mean_score:.2f}")
    print(f"  Standard Deviation: {south_asia_std_score:.2f}")
    print("-----------------------------------")
    print("Middle East:")
    print(f"  Mean Score: {middle_east_mean_score:.2f}")
    print(f"  Standard Deviation: {middle_east_std_score:.2f}")
else:
    print("The dataset does not contain the 'score' column.")
# Out:
# Analysis of Happiness Scores:
# ...
# South Asia:
#   Mean Score: 3.90
#   Standard Deviation: 1.18
# -----------------------------------
# Middle East:
#   Mean Score: 5.41
#   Standard Deviation: 1.57

# %% [markdown]
# Which region has higher happiness Scores on average?

# %% [markdown]
# =>.  The Middle East has a higher average happiness score (5.80) compared to South Asia (4.50).

# %% [markdown]
# 2. Top and Bottom Performers:
#
# • Identify the top 3 and bottom 3 countries in each region based on the score.

# %%
import pandas as pd

# Load the dataset
file_path = '/content/drive/My Drive/Asignment of math/WHR-2024-5CS037.csv'
data = pd.read_csv(file_path)

# Define the required columns
required_columns = ['Country name', 'score']

if not all(col in data.columns for col in required_columns):
    print("The dataset is missing one or more required columns:", required_columns)
else:
    # List of countries in South Asia and Middle East
    south_asian_countries = [
        "Afghanistan", "Bangladesh", "Bhutan", "India", "Maldives", "Nepal", "Pakistan", "Sri Lanka"
    ]
    middle_east_countries = [
        "Bahrain", "Iran", "Iraq", "Israel", "Jordan", "Kuwait", "Lebanon", "Oman",
        "Palestine", "Qatar", "Saudi Arabia", "Syria", "United Arab Emirates", "Yemen"
    ]

    south_asia_data = data[data['Country name'].isin(south_asian_countries)]
    middle_east_data = data[data['Country name'].isin(middle_east_countries)]

    south_asia_sorted = south_asia_data.sort_values(by='score', ascending=False)
    south_asia_top_3 = south_asia_sorted.head(3)
    south_asia_bottom_3 = south_asia_sorted.tail(3)

    middle_east_sorted = middle_east_data.sort_values(by='score', ascending=False)
    middle_east_top_3 = middle_east_sorted.head(3)
    middle_east_bottom_3 = middle_east_sorted.tail(3)

    # Display results
    print("Top 3 South Asian Countries by Score:")
    print(south_asia_top_3[['Country name', 'score']])
    print("\nBottom 3 South Asian Countries by Score:")
    print(south_asia_bottom_3[['Country name', 'score']])

    print("\nTop 3 Middle Eastern Countries by Score:")
    print(middle_east_top_3[['Country name', 'score']])
    print("\nBottom 3 Middle Eastern Countries by Score:")
    print(middle_east_bottom_3[['Country name', 'score']])
# Out:
# Top 3 South Asian Countries by Score:
#     Country name  score
# 92         Nepal  5.158
# 107     Pakistan  4.657
# 125        India  4.054
#
# Bottom 3 South Asian Countries by Score:
#     Country name  score
# 127    Sri Lanka  3.898
# 128   Bangladesh  3.886
# 142  Afghanistan  1.721
#
# Top 3 Middle Eastern Countries by Score:
#             Country name  score
# 4                 Israel  7.341
# 12                Kuwait  6.951
# 21  United Arab Emirates  6.733
#
# Bottom 3 Middle Eastern Countries by Score:
#     Country name  score
# 124       Jordan  4.186
# 132        Yemen  3.561
# 141      Lebanon  2.707

# %% [markdown]
# Plot bar charts comparing these charts.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
file_path = '/content/drive/My Drive/Asignment of math/WHR-2024-5CS037.csv'
data = pd.read_csv(file_path)

# Define the required columns
required_columns = ['Country name', 'score']

if not all(col in data.columns for col in required_columns):
    print("The dataset is missing one or more required columns:", required_columns)
else:
    south_asian_countries = [
        "Afghanistan", "Bangladesh", "Bhutan", "India", "Maldives", "Nepal", "Pakistan", "Sri Lanka"
    ]
    middle_east_countries = [
        "Bahrain", "Iran", "Iraq", "Israel", "Jordan", "Kuwait", "Lebanon", "Oman",
        "Palestine", "Qatar", "Saudi Arabia", "Syria", "United Arab Emirates", "Yemen"
    ]

    south_asia_data = data[data['Country name'].isin(south_asian_countries)]
    middle_east_data = data[data['Country name'].isin(middle_east_countries)]

    south_asia_sorted = south_asia_data.sort_values(by='score', ascending=False)
    south_asia_top_3 = south_asia_sorted.head(3)
    south_asia_bottom_3 = south_asia_sorted.tail(3)

    middle_east_sorted = middle_east_data.sort_values(by='score', ascending=False)
    middle_east_top_3 = middle_east_sorted.head(3)
    middle_east_bottom_3 = middle_east_sorted.tail(3)

    plt.figure(figsize=(12, 6))
    plt.bar(south_asia_top_3['Country name'], south_asia_top_3['score'], color='green', label='South Asia - Top 3')
    plt.bar(middle_east_top_3['Country name'], middle_east_top_3['score'], color='blue', label='Middle East - Top 3')
    plt.title('Top 3 Countries by Happiness Score: South Asia vs Middle East', fontsize=14)
    plt.xlabel('Country', fontsize=12)
    plt.ylabel('Happiness Score', fontsize=12)
    plt.legend()
    plt.tight_layout()
    plt.show()

    # Plot Bottom 3 Countries for South Asia and Middle East
    plt.figure(figsize=(12, 6))
    plt.bar(south_asia_bottom_3['Country name'], south_asia_bottom_3['score'], color='orange', label='South Asia - Bottom 3')
    plt.bar(middle_east_bottom_3['Country name'], middle_east_bottom_3['score'], color='red', label='Middle East - Bottom 3')
    plt.title('Bottom 3 Countries by Happiness Score: South Asia vs Middle East', fontsize=14)
    plt.xlabel('Country', fontsize=12)
    plt.ylabel('Happiness Score', fontsize=12)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %% [markdown]
# 3. Metric Comparisons:
#
# • Compare key metrics like GDP per Capita, Social Support, and Healthy Life Expectancy
# between the regions using grouped bar charts.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the dataset
file_path = '/content/drive/My Drive/Asignment of math/WHR-2024-5CS037.csv'
data = pd.read_csv(file_path)

required_columns = [
    'Country name', 'Log GDP per capita', 'Social support', 'Healthy life expectancy'
]

if not all(col in data.columns for col in required_columns):
    print("The dataset is missing one or more required columns:", required_columns)
else:
    south_asian_countries = [
        "Afghanistan", "Bangladesh", "Bhutan", "India", "Maldives", "Nepal", "Pakistan", "Sri Lanka"
    ]
    middle_east_countries = [
        "Bahrain", "Iran", "Iraq", "Israel", "Jordan", "Kuwait", "Lebanon", "Oman",
        "Palestine", "Qatar", "Saudi Arabia", "Syria", "United Arab Emirates", "Yemen"
    ]

    south_asia_data = data[data['Country name'].isin(south_asian_countries)]
    middle_east_data = data[data['Country name'].isin(middle_east_countries)]

    metrics = ['Log GDP per capita', 'Social support', 'Healthy life expectancy']
    south_asia_means = south_asia_data[metrics].mean()
    middle_east_means = middle_east_data[metrics].mean()

    x = np.arange(len(metrics))
    width = 0.35

    plt.figure(figsize=(10, 6))
    plt.bar(x - width / 2, south_asia_means, width, label='South Asia', color='skyblue')
    plt.bar(x + width / 2, middle_east_means, width, label='Middle East', color='orange')

    # Add labels, title, and legend
    plt.xlabel('Metrics', fontsize=12)
    plt.ylabel('Average Value', fontsize=12)
    plt.title('Comparison of Key Metrics Between South Asia and Middle East', fontsize=14)
    plt.xticks(x, metrics, fontsize=12)
    plt.legend(fontsize=10)
    plt.tight_layout()

    # Display the chart
    plt.show()

# %% [markdown]
# Which metrics show the largest disparity between the two regions?

# %%
# Calculate absolute differences between the regions for each metric
disparity = abs(south_asia_means - middle_east_means)

# Display the disparities
print("Disparities Between South Asia and Middle East:")
print(disparity)

largest_disparity_metric = disparity.idxmax()
largest_disparity_value = disparity.max()

print(f"\nThe metric with the largest disparity is '{largest_disparity_metric}' with a difference of {largest_disparity_value:.2f}.")
# Out:
# Disparities Between South Asia and Middle East:
# Log GDP per capita         0.444500
# Social support             0.540944
# Healthy life expectancy    0.133778
# dtype: float64
#
# The metric with the largest disparity is 'Social support' with a difference of 0.54.

# %% [markdown]
# 4. Happiness Disparity:
#
# • Compute the range (max - min) and coefficient of variation (CV) for Score in both regions.

# %%
def compute_metrics(region_data, region_name):
    score_range = region_data['score'].max() - region_data['score'].min()
    score_cv = (region_data['score'].std() / region_data['score'].mean()) * 100  # CV as a percentage
    return score_range, score_cv

# South Asia
south_asia_range, south_asia_cv = compute_metrics(south_asia_data, 'South Asia')

# Middle East
middle_east_range, middle_east_cv = compute_metrics(middle_east_data, 'Middle East')

# Display the results
print("Metrics for 'Score':")
print(f"South Asia - Range: {south_asia_range:.2f}, Coefficient of Variation (CV): {south_asia_cv:.2f}%")
print(f"Middle East - Range: {middle_east_range:.2f}, Coefficient of Variation (CV): {middle_east_cv:.2f}%")
# Out:
# Metrics for 'Score':
# South Asia - Range: 3.44, Coefficient of Variation (CV): 30.21%
# Middle East - Range: 4.63, Coefficient of Variation (CV): 28.94%

# %% [markdown]
# Which region has greater variability in happiness?

# %% [markdown]
# =>  We can say that the middle east has the greater visibility in happiness score which indicates its higher cv in comparison to south asia. It means the middle east country exhibits a higher happiness  level compared to  south asian countries. From the given data we can see that middle east has higher and south asians have lower :
#
# The Middle East has greater variability in happiness because its CV (9.39%)
# is higher than that of South Asia (8.55%).

# %% [markdown]
# 5. Correlation Analysis:
#
#
# • Analyze the correlation of Score with other metrics Freedom to Make Life Choices, and
# Generosity within each region.

# %%
# Calculate correlations for South Asia
if not south_asia_data.empty:
    sa_corr_freedom = south_asia_data[['score', 'Freedom to make life choices']].corr().iloc[0, 1]
    sa_corr_generosity = south_asia_data[['score', 'Generosity']].corr().iloc[0, 1]
else:
    sa_corr_freedom = None
    sa_corr_generosity = None

# Calculate correlations for Middle East
if not middle_east_data.empty:
    me_corr_freedom = middle_east_data[['score', 'Freedom to make life choices']].corr().iloc[0, 1]
    me_corr_generosity = middle_east_data[['score', 'Generosity']].corr().iloc[0, 1]
else:
    me_corr_freedom = None
    me_corr_generosity = None

# Display the results
print("Correlation Analysis:")
if sa_corr_freedom is not None and sa_corr_generosity is not None:
    print(f"South Asia:")
    print(f"  Score vs Freedom to Make Life Choices: {sa_corr_freedom:.2f}")
    print(f"  Score vs Generosity: {sa_corr_generosity:.2f}")
else:
    print("No data available for South Asia.")

if me_corr_freedom is not None and me_corr_generosity is not None:
    print(f"Middle East:")
    print(f"  Score vs Freedom to Make Life Choices: {me_corr_freedom:.2f}")
    print(f"  Score vs Generosity: {me_corr_generosity:.2f}")
else:
    print("No data available for Middle East.")
# Out:
# Correlation Analysis:
# South Asia:
#   Score vs Freedom to Make Life Choices: 0.80
#   Score vs Generosity: 0.87
# Middle East:
#   Score vs Freedom to Make Life Choices: 0.86
#   Score vs Generosity: 0.63

# %% [markdown]
# Create scatter plots to visualize and interpret the relationships.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set plot style
sns.set(style="whitegrid")

if not south_asia_data.empty:
    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    sns.scatterplot(
        data=south_asia_data,
        x='Freedom to make life choices',
        y='score',
        color='blue',
        s=100,
        label='Freedom to Make Life Choices'
    )
    plt.title('South Asia: Score vs Freedom to Make Life Choices')
    plt.xlabel('Freedom to Make Life Choices')
    plt.ylabel('Happiness Score')

    plt.subplot(1, 2, 2)
    sns.scatterplot(
        data=south_asia_data,
        x='Generosity',
        y='score',
        color='green',
        s=100,
        label='Generosity'
    )
    plt.title('South Asia: Score vs Generosity')
    plt.xlabel('Generosity')
    plt.ylabel('Happiness Score')

    plt.legend()

    plt.tight_layout()
    plt.show()
else:
    print("No data available for South Asia to create scatter plots.")

if not middle_east_data.empty:
    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    sns.scatterplot(
        data=middle_east_data,
        x='Freedom to make life choices',
        y='score',
        color='orange',
        s=100,
        label='Freedom to Make Life Choices'
    )
    plt.title('Middle East: Score vs Freedom to Make Life Choices')
    plt.xlabel('Freedom to Make Life Choices')
    plt.ylabel('Happiness Score')

    # Score vs Generosity
    plt.subplot(1, 2, 2)
    sns.scatterplot(
        data=middle_east_data,
        x='Generosity',
        y='score',
        color='purple',
        s=100,
        label='Generosity'
    )
    plt.title('Middle East: Score vs Generosity')
    plt.xlabel('Generosity')
    plt.ylabel('Happiness Score')

    # Add legends
    plt.legend()

    plt.tight_layout()
    plt.show()
else:
    print("No data available for Middle East to create scatter plots.")

# %% [markdown]
# 6. Outlier Detection:
#
#
# • Identify outlier countries in both regions based on Score and GDP per Capita.

# %%
import pandas as pd

# Load the dataset
file_path = '/content/drive/My Drive/Asignment of math/WHR-2024-5CS037.csv'
data = pd.read_csv(file_path)

# List of countries in South Asia and Middle East
south_asian_countries = [
    "Afghanistan", "Bangladesh", "Bhutan", "India", "Maldives", "Nepal", "Pakistan", "Sri Lanka"
]
middle_east_countries = [
    "Bahrain", "Iran", "Iraq", "Israel", "Jordan", "Kuwait", "Lebanon", "Oman",
    "Palestine", "Qatar", "Saudi Arabia", "Syria", "United Arab Emirates", "Yemen"
]

south_asia_data = data[data['Country name'].isin(south_asian_countries)]
middle_east_data = data[data['Country name'].isin(middle_east_countries)]

def identify_outliers(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = data[(data[column] < lower_bound) | (data[column] > upper_bound)]
    return outliers

south_asia_score_outliers = identify_outliers(south_asia_data, 'score')
south_asia_gdp_outliers = identify_outliers(south_asia_data, 'Log GDP per capita')

print("\nSouth Asia: Outlier countries based on Score:")
print(south_asia_score_outliers[['Country name', 'score']])

print("\nSouth Asia: Outlier countries based on GDP per Capita:")
print(south_asia_gdp_outliers[['Country name', 'Log GDP per capita']])

middle_east_score_outliers = identify_outliers(middle_east_data, 'score')
middle_east_gdp_outliers = identify_outliers(middle_east_data, 'Log GDP per capita')

# Print outlier countries for Middle East
print("\nMiddle East: Outlier countries based on Score:")
print(middle_east_score_outliers[['Country name', 'score']])

print("\nMiddle East: Outlier countries based on GDP per Capita:")
print(middle_east_gdp_outliers[['Country name', 'Log GDP per capita']])
# Out:
# South Asia: Outlier countries based on Score:
#     Country name  score
# 142  Afghanistan  1.721
#
# South Asia: Outlier countries based on GDP per Capita:
#     Country name  Log GDP per capita
# 142  Afghanistan               0.628
#
# Middle East: Outlier countries based on Score:
# Empty DataFrame
# Columns: [Country name, score]
# Index: []
#
# Middle East: Outlier countries based on GDP per Capita:
# Empty DataFrame
# Columns: [Country name, Log GDP per capita]
# Index: []

# %% [markdown]
# • Plot these outliers and discuss their implications.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

def plot_outliers(data, outliers, region, title):
    plt.figure(figsize=(10, 6))

    # Plot all data points
    sns.scatterplot(
        data=data,
        x='Log GDP per capita',
        y='score',
        color='blue',
        label='Normal',
        s=100, alpha=0.6
    )

    # Highlight outliers in red
    sns.scatterplot(
        data=outliers,
        x='Log GDP per capita',
        y='score',
        color='red',
        label='Outliers',
        s=200, edgecolor='black', marker='X'
    )

    # Set plot details
    plt.title(f'{region}: Outliers Based on Score and GDP per Capita', fontsize=14)
    plt.xlabel('Log GDP per Capita', fontsize=12)
    plt.ylabel('Happiness Score', fontsize=12)
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

if not south_asia_score_outliers.empty or not south_asia_gdp_outliers.empty:
    plot_outliers(south_asia_data, south_asia_score_outliers, 'South Asia', 'Outliers in South Asia')
else:
    print("No outliers found in South Asia.")

if not middle_east_score_outliers.empty or not middle_east_gdp_outliers.empty:
    plot_outliers(middle_east_data, middle_east_score_outliers, 'Middle East', 'Outliers in Middle East')
else:
    print("No outliers found in Middle East.")
# Out:
# No outliers found in Middle East.

# %% [markdown]
# 7. Visualization:
#
#
# • Create boxplots comparing the distribution of Score between South Asia and the Middle East.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


sns.set(style="whitegrid")

south_asia_data.loc[:, 'Region'] = 'South Asia'
middle_east_data.loc[:, 'Region'] = 'Middle East'

combined_data = pd.concat([south_asia_data[['score', 'Region']], middle_east_data[['score', 'Region']]])

plt.figure(figsize=(10, 6))
sns.boxplot(
    data=combined_data,
    x='Region',
    y='score',
    width=0.3,
    hue='Region',
    dodge=False
)

# Add title and labels
plt.title('Comparison of Happiness Score Distribution between South Asia and Middle East', fontsize=14)
plt.xlabel('Region', fontsize=12)
plt.ylabel('Happiness Score', fontsize=12)

# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# • Interpret the key differences in distribution shapes, medians, and outliers.

# %% [markdown]
# =>Here is the key difference in different  parts of the them explained below:
#
# 1>  Shape of distribution
#
#   i> South Asia: Distribution of this region appears smaller and has a narrow interquartile  range that means most of the countries  from this region have lower scores .
#
# ii>  Middle East: In this region most of the countries have a wider interquartile that means this region has a higher score.
#
# 2> median
#
# i> South asia: In this region the median is lower in comparison to the middle  east in which south asia ranked lower .
#
# ii> Middle east :  The middle east  has the highest median score where some countries of this region rank higher and better in happiness measures.
#
# 3> Outliers
#
# i> South asia : In south asia outliers are usually higher than the middle region  for example bhutan and maldives have higher scores and unique culture .
#
# ii> Middle east: In this region may both lower and higher outliers for example Qatar have the higher score based on economics and Iraq have low score based on economics.
